# %% [markdown]
# Reading the csv files with image directories and labels

# %%
import numpy as np
import pandas as pd
import os

#for dirname, _, filenames in os.walk('./EMNIST'):
#    for filename in filenames:
#        print(os.path.join(dirname, filename))

# %%
testing_letter = pd.read_csv('./EMNIST/emnist-letters-test.csv')
training_letter = pd.read_csv('./EMNIST/emnist-letters-train.csv')
print(training_letter.shape)
print(testing_letter.shape)
# Out:
# (88799, 785)
# (14799, 785)

# %% [markdown]
# Introduce into x and y variables

# %%
#training_letters
y1 = np.array(training_letter.iloc[:,0].values)
x1 = np.array(training_letter.iloc[:,1:].values)
#testing_labels
y2 = np.array(testing_letter.iloc[:,0].values)
x2 = np.array(testing_letter.iloc[:,1:].values)
print(y1.shape)
print(x1.shape)
# Out:
# (88799,)
# (88799, 784)

# %% [markdown]
# Plot some of the data

# %%
import matplotlib.pyplot as plt 
fig,axes = plt.subplots(3,5,figsize=(10,8))
for i,ax in enumerate(axes.flat):
    ax.imshow(x1[i].reshape([28,28]))

# %% [markdown]
# PREPROCESSING OF THE DATA

# %%
import tensorflow as tf

# Normalise and reshape data
train_images = x1 / 255.0
test_images = x2 / 255.0

train_images_number = train_images.shape[0]
train_images_height = 28
train_images_width = 28
train_images_size = train_images_height*train_images_width

train_images = train_images.reshape(train_images_number, train_images_height, train_images_width, 1)

test_images_number = test_images.shape[0]
test_images_height = 28
test_images_width = 28
test_images_size = test_images_height*test_images_width

test_images = test_images.reshape(test_images_number, test_images_height, test_images_width, 1)


# Transform labels
number_of_classes = 27

y1 = tf.keras.utils.to_categorical(y1, number_of_classes)
y2 = tf.keras.utils.to_categorical(y2, number_of_classes)

# %% [markdown]
# Generating CNN

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau,ModelCheckpoint
from sklearn.model_selection import train_test_split

train_x,test_x,train_y,test_y = train_test_split(train_images,y1,test_size=0.2,random_state = 42)

model = tf.keras.Sequential([ 
    tf.keras.layers.Conv2D(32,3,input_shape=(28,28,1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(input_shape=(28,28,1)),
    tf.keras.layers.Dense(512,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(number_of_classes,activation='softmax')
])

model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# Adding Callback API's to save best weights and change lr

# %%
MCP = ModelCheckpoint('Best_points.h5',verbose=1,save_best_only=True,monitor='val_accuracy',mode='max')
ES = EarlyStopping(monitor='val_accuracy',min_delta=0,verbose=0,restore_best_weights = True,patience=3,mode='max')
RLP = ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.2,min_lr=0.0001)

# %% [markdown]
# Let's train!

# %%
history = model.fit(train_x,train_y,
epochs=10,validation_data=(test_x,test_y),callbacks=[MCP,ES,RLP])
# Out:
# Epoch 1/10
# 2215/2220 [============================>.] - ETA: 0s - loss: 0.5546 - accuracy: 0.8260
# Epoch 1: val_accuracy improved from -inf to 0.88407, saving model to Best_points.h5
# 2220/2220 [==============================] - 9s 3ms/step - loss: 0.5539 - accuracy: 0.8262 - val_loss: 0.3658 - val_accuracy: 0.8841 - lr: 0.0010
# Epoch 2/10
# 2212/2220 [============================>.] - ETA: 0s - loss: 0.2789 - accuracy: 0.9097
# Epoch 2: val_accuracy improved from 0.88407 to 0.89848, saving model to Best_points.h5
# 2220/2220 [==============================] - 6s 3ms/step - loss: 0.2789 - accuracy: 0.9098 - val_loss: 0.3188 - val_accuracy: 0.8985 - lr: 0.0010
# Epoch 3/10
# 2215/2220 [============================>.] - ETA: 0s - loss: 0.2190 - accuracy: 0.9279
# Epoch 3: val_accuracy improved from 0.89848 to 0.89972, saving model to Best_points.h5
# 2220/2220 [==============================] - 6s 3ms/step - loss: 0.2190 - accuracy: 0.9279 - val_loss: 0.3453 - val_accuracy: 0.8997 - lr: 0.0010
# Epoch 4/10
# 2202/2220 [============================>.] - ETA: 0s - loss: 0.1863 - accuracy: 0.9373
# Epoch 4: val_accuracy improved from 0.89972 to 0.90321, saving model to Best_points.h5
# 2220/2220 [==============================] - 6s 3ms/step - loss: 0.1863 - accuracy: 0.9374 - val_loss: 0.3441 - val_accuracy: 0.9032 - lr: 0.0010
# Epoch 5/10
# 2211/2220 [============================>.] - ETA: 0s - loss: 0.1687 - accuracy: 0.9442
# Epoch 5: val_accuracy did not improve from 0.90321
# 2220/2220 [==============================] - 6s 3ms/step - loss: 0.1692 - accuracy: 0.9441 - val_loss: 0.4459 - val_accuracy: 0.8877 - lr: 0.0010
# Epoch 6/10
# 2220/2220 [==============================] - ETA: 0s - loss: 0.0812 - accuracy: 0.9698
# Epoch 6: val_accuracy improved from 0.90321 to 0.91430, saving model to Best_points.h5
# 2220/2220 [==============================] - 6s 3ms/step - loss: 0.0812 - accuracy: 0.9698 - val_loss: 0.3874 - val_accuracy: 0.9143 - lr: 2.0000e-04
# Epoch 7/10
# 2204/2220 [============================>.] - ETA: 0s - loss: 0.0663 - accuracy: 0.9749
# Epoch 7: val_accuracy improved from 0.91430 to 0.91768, saving model to Best_points.h5
# 2220/2220 [==============================] - 6s 3ms/step - loss: 0.0662 - accuracy: 0.9749 - val_loss: 0.4086 - val_accuracy: 0.9177 - lr: 2.0000e-04
# Epoch 8/10
# 2212/2220 [============================>.] - ETA: 0s - loss: 0.0609 - accuracy: 0.9760
# Epoch 8: val_accuracy did not improve from 0.91768
# 2220/2220 [==============================] - 6s 3ms/step - loss: 0.0610 - accuracy: 0.9759 - val_loss: 0.4177 - val_accuracy: 0.9145 - lr: 2.0000e-04
# Epoch 9/10
# 2209/2220 [============================>.] - ETA: 0s - loss: 0.0499 - accuracy: 0.9806
# Epoch 9: val_accuracy did not improve from 0.91768
# 2220/2220 [==============================] - 6s 3ms/step - loss: 0.0499 - accuracy: 0.9805 - val_loss: 0.4439 - val_accuracy: 0.9150 - lr: 1.0000e-04
# Epoch 10/10
# 2202/2220 [============================>.] - ETA: 0s - loss: 0.0476 - accuracy: 0.9812
# Epoch 10: val_accuracy did not improve from 0.91768
# 2220/2220 [==============================] - 6s 3ms/step - loss: 0.0475 - accuracy: 0.9812 - val_loss: 0.4439 - val_accuracy: 0.9146 - lr: 1.0000e-04

# %% [markdown]
# Let's plot acc vs val_acc

# %%
import seaborn as sns

q = len(history.history['accuracy'])

plt.figsize=(10,10)
sns.lineplot(x = range(1,1+q),y = history.history['accuracy'], label='Accuracy')
sns.lineplot(x = range(1,1+q),y = history.history['val_accuracy'], label='Val_Accuracy')
plt.xlabel('epochs')
plt.ylabel('Accuracy')
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# Text(0, 0.5, 'Accuracy')

# %%
fig,axes = plt.subplots(13,2,figsize=(80,80))

for i,ax in enumerate(axes.flat):
    pos = np.where(np.where(y1==1)[1] == i+1)
    ax.imshow(np.transpose(x1[pos[0][0]].reshape([28,28])))

# %%
import cv2          #Computer vision library

img = cv2.imread("correctS.png")
plt.imshow(img)

# %%
# Convert the image to gray scale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Performing OTSU threshold
ret, thresh1 = cv2.threshold(gray, 0, 255, cv2.THRESH_OTSU | cv2.THRESH_BINARY_INV)


test_images = thresh1 / 255.0

    
test_images = cv2.resize(test_images, (28,28), interpolation = cv2.INTER_AREA)

plt.imshow(test_images)

# %%
list(y_pred).index(val)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-bff83469d45a> in <module>
# ----> 1 list(y_pred).index(val)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
test_images_number = 1
test_images_height = 28
test_images_width = 28
test_images_size = test_images_height*test_images_width

test_images = test_images.reshape(test_images_number, test_images_height, test_images_width, 1)


y_pred = model.predict(np.transpose(test_images))
# Out:
# 1/1 [==============================] - 0s 13ms/step

# %%
true_index = list("abcdefghijklmnopqrstuvwxyz").index('s')

print(y_pred[0][true_index+1])
# Out:
# 1.0
